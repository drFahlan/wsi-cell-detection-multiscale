# %% [markdown]
# # Notebook 03 — Multi-Scale Cell Detection
#
# Extends the baseline by incorporating tissue-level WSI crops as a second input channel, providing broader spatial context to the cell detection model.
#
# > **Full version with outputs:** [Google Drive]()
#
# This notebook is stripped of outputs. Run on Google Colab with the dataset mounted from Google Drive.
