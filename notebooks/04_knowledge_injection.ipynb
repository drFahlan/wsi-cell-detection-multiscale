# %% [markdown]
# # Notebook 04 — Knowledge Injection via Tissue Segmentation
#
# Uses tissue segmentation predictions as an auxiliary signal to guide cell detection, injecting spatial tissue-type context into the primary detection pipeline.
#
# > **Full version with outputs:** [Google Drive]()
#
# This notebook is stripped of outputs. Run on Google Colab with the dataset mounted from Google Drive.
