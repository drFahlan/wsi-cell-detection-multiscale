# %% [markdown]
# # Notebook 02 — Baseline: Single-Scale Cell Detection
#
# Single-scale pipeline using cell-level crops only. Establishes the performance baseline for comparison against multi-scale and knowledge injection variants.
#
# > **Full version with outputs:** [Google Drive]()
#
# This notebook is stripped of outputs. Run on Google Colab with the dataset mounted from Google Drive.
